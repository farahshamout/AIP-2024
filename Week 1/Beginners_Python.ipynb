# %% [markdown]
# ## An Introduction to Python
# This python notebooks covers the basics of the python scripting language, as well as the use of a few libraries that are commonly used for machine learning.
#
# As mentioned, throughout this notebook we wil be using python libraries, which are little packages of code which have been written by other people which we can import into our script. These save us having to write complicated algorithms ourselves.
#
# The commonly used ones that we'll be using are often downloaded as standard in many python environments, however if they are not, then try running the cell at the end of this notebook to install them.

# %% [markdown]
# ## Python Fundamentals
#
# Using python you can can print text and do basic arithmetic as seen in the cell below.
#
# Any text that follows a (#) symbol is called a comment, and is used to insert text which can be useful for explaining lines of code.

# %%
# Printing "Hello world"
print("Hello world")

# Adding two numbers
a = 5
b = 10
sum_ab = a + b
print(sum_ab)
# Out:
# Hello world
# 15

# %% [markdown]
# In Python, a list is a versatile and commonly used data structure that allows you to store a collection of items.

# %%
# c. Defining a list
my_list = [1, 2, 3, 4, 5]
print("List:", my_list) # this prints the word "List" followed by the variable called "my_list" which was made above
# Out:
# List: [1, 2, 3, 4, 5]

# %% [markdown]
# ## Dataframes
# A pandas DataFrame is a two-dimensional, labeled data structure commonly used for data manipulation and analysis in Python. It resembles a table or spreadsheet with rows and columns, where each column can have a different data type.
#
# This uses the library "Pandas" and so it needs to be imported at the start.

# %%
# Import necessary libraries
import pandas as pd

# Creating a dataframe using pandas
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 40]}
df = pd.DataFrame(data)
print("DataFrame:")
print(df)
# Out:
# DataFrame:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %% [markdown]
# Dataframes will hold data while the python development environment is running, but when you close this window this data will be lost. One good way of saving the data permenently is to save it in a CSV file like so:

# %%
# Write DataFrame to CSV file
df.to_csv('data.csv', index=False)

print("CSV file written successfully.")
# Out:
# CSV file written successfully.

# %% [markdown]
# Dataframes are a great way of storing and manipulating data, but the first hurdle is getting the data into a dataframe initially.
#
#
# One way of doing this is from a list.
#
# Remember that list we made earlier? That was a simple list of numbers. Each item in a list can in fact be another list. The example below shows how this can be a useful thing to do:

# %%
data_list = [['Alice', 25], ['Bob', 30], ['Charlie', 35], ['David', 40]]
print("Data list:", data_list)
# Out:
# Data list: [['Alice', 25], ['Bob', 30], ['Charlie', 35], ['David', 40]]

# %% [markdown]
# We can now populate a dataframe using this list:

# %%
# Filling a dataframe from a list
df_from_list = pd.DataFrame(data_list, columns=['Name', 'Age'])
print("DataFrame from list:")
print(df_from_list)
# Out:
# DataFrame from list:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %% [markdown]
# Another way of populating a dataframe is from a CSV file. Here we'll use the one we made earlier:

# %%
# Filling a dataframe from a csv file
df_from_csv = pd.read_csv('data.csv')
print("DataFrame from CSV:")
print(df_from_csv)
# Out:
# DataFrame from CSV:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %% [markdown]
# A useful feature of a pandas dataframe is the ability to create data summaries. Here's an example of this:

# %%
# Summary data from a dataframe (.mean, .min, .describe etc.)
print("Mean Age:", df['Age'].mean())
print("Minimum Age:", df['Age'].min())
print("Description:")
print(df.describe())
# Out:
# Mean Age: 32.5
# Minimum Age: 25
# Description:
#              Age
# count   4.000000
# mean   32.500000
# std     6.454972
# min    25.000000
# 25%    28.750000
# 50%    32.500000
# 75%    36.250000
# max    40.000000

# %% [markdown]
# ## Plotting Data
#
# Data from a dataframe can be plotted to present the data in a human readable way for analysis.
#
# A good library for this is MatPlotLib. We generate the data here using a library called Numpy:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data
t = np.arange(0.0, 2.0, 0.01) #This produces a list which ranges from the number 0.0 to 2.0 in steps of 0.01
s = np.sin(2 * np.pi * t)

# Create a DataFrame
df = pd.DataFrame({'Time (s)': t, 'Voltage (mV)': s})

# Plotting
fig, ax = plt.subplots()
df.plot(x='Time (s)', y='Voltage (mV)', ax=ax)

# Set labels and title
ax.set(xlabel='Time (s)', ylabel='Voltage (mV)', title='Simple Sine Wave')

# Add grid
ax.grid()

plt.show()

# %%
import random # We use this library for making random numbers to make our data look interesting

# Generate random ages for 50 students
random.seed(0)  # For reproducibility
ages = [random.randint(18, 24) for _ in range(50)]

# Create a DataFrame with the generated ages
data = {'Name': [f"Student {i}" for i in range(1, 51)],
        'Age': ages}
df = pd.DataFrame(data)

# Histogram
df['Age'].plot(kind='hist', bins=7, edgecolor='black', alpha=0.7)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)  # Add grid lines
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# ## Your first machine learning algorithm!
#
# The cells below show you how simple it is to use the SKLearn library to both create data, and then run a k-means clustering algorithm on the data to predict clusters.

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generating 2D data using sklearn 'blobs'
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.title('Generated Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# Clustering of the data using sklearn k-means
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5)
plt.title('Clustering Results')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ## Library install notes:
# Run the cell below if you haven't got these libraries installed.

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
