# %% [markdown]
# # LLMs via APIs
#
# In this session we will cover...
#
#
# *   List item
# *   List item

# %% [markdown]
# ### [1] Set up your API and required keys

# %%
  api_key='sk-students-oeD5lGOU95Q5qbn1GCOBT3BlbkFJsMac71yA20yzyGjbGdcy'
  organizationID='org-1MmgzkePqkBwRO2aykIjqIkw'
  projectID='proj_oNhMie7bUL5JKObfNNr9tKNE'

# %%
# Install OpenAI library
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.4/327.4 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
# ...

# %%
from openai import OpenAI

client = OpenAI(
  api_key=api_key,
  organization=organizationID,
  project=projectID,
)

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-16k",
  messages=[{"role": "user", "content": "Say this is a test"}],
)

print(completion.choices[0].message.content)
# Out:
# This is a test.

# %% [markdown]
# ## Todo:
#
# Common Benchmark Tasks:
#
# *   Q&A multiple choice vs free text response
# *   Open vs closed domain
#
# Prompting strategies:
# * zero shot prompting
# * few shot prompting
#
# Customize the model for a specific domain:
# * publicly available datasets (a few examples)
# * fine tuning (Demo but do not exercise)

# %%
 prompt = "Your prompt goes here"

completion = client.chat.completions.create(
  model="gpt-3.5-turbo-16k",
  messages=[{"role": "user", "content": prompt}],
)

print(completion.choices[0].message.content)

# %%
stream = client.chat.completions.create(
    model="gpt-3.5-turbo-16k",
    messages=[
      {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
      {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
    ],
    stream=True,
)
for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# In the realm of code, a dance I share,
# Where repetition weaves its snare,
# A concept known as recursion dwells,
# A loop that within itself compels.
#
# Like a mirror's echo, it repeats,
# A pattern unfurling, as fate decrees,
# Infinite reflections, it unfolds,
# As the story of a myth that's told.
#
# A function calls itself, you see,
# With parameters passed willingly,
# Solving problems, layer by layer,
# Unraveling mysteries with a flair.
#
# Like a fractal, expanding wide,
# Recursive tales within reside,
# Each task, into smaller fragments torn,
# Until the base case, the code adorns.
#
# A labyrinth within the code's abyss,
# With boundaries that sometimes amiss,
# The beauty lies in its power to delve,
# Solving puzzles, it excels.
#
# Yet, with great power comes caution's plea,
# For an endless loop, recursion can be,
# A stack overflow, a memory strained,
# If not cautiously restrained.
#
# But fear not, for understanding's key,
# To tame the beast, set the code free,
# ...
